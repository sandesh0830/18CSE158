# %% [markdown]
# <a href="https://colab.research.google.com/github/sandesh0830/18CSE158/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ASSIGNMENT-4**
# **NAME - SANDESH KUMAR BEHERA**
#
# **ROLL NO - 18CSE158**
#
# **SUBJECT - DMDW LAB**

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-219c7308-22f6-492c-a723-37ddb9d6c931" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-219c7308-22f6-492c-a723-37ddb9d6c931">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving matches.csv to matches (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['matches.csv']))  
df
# Out:
#         id    Season  ...         umpire2                  umpire3
# 0        1  IPL-2017  ...        NJ Llong                      NaN
# 1        2  IPL-2017  ...          S Ravi                      NaN
# 2        3  IPL-2017  ...       CK Nandan                      NaN
# 3        4  IPL-2017  ...   C Shamshuddin                      NaN
# 4        5  IPL-2017  ...             NaN                      NaN
# ..     ...       ...  ...             ...                      ...
# 751  11347  IPL-2019  ...        O Nandan                   S Ravi
# 752  11412  IPL-2019  ...     Nitin Menon                Ian Gould
# 753  11413  IPL-2019  ...             NaN                      NaN
# 754  11414  IPL-2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415  IPL-2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=756, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df["umpire3"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["city"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["winner"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["player_of_match"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["umpire1"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["umpire2"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %% [markdown]
# **The data is cleaned and ready to be used .**

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="Season",
    color="red")
plt.title("Season Count")
# Out:
# Text(0.5, 1.0, 'Season Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(44,8))
sns.histplot(
    df,
    x="city",
    color="blue")
plt.title("city Count")
# Out:
# Text(0.5, 1.0, 'city Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(42,8))
sns.histplot(
    df,
    x="team1",
    color="orange")
plt.title("team1 Count")
# Out:
# Text(0.5, 1.0, 'team1 Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(44,8))
sns.histplot(
    df,
    x="team2",
    color="orange")
plt.title("team2 Count")
# Out:
# Text(0.5, 1.0, 'team2 Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="result",
    hue="result")
plt.title("result Count")
# Out:
# Text(0.5, 1.0, 'result Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(30,8))
sns.histplot(
    df,
    x="toss_decision",
    hue="toss_decision")
plt.title("toss_decision Count")
# Out:
# Text(0.5, 1.0, 'toss_decision Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(40,8))
sns.histplot(
    df,
    x="winner",
    color="red")
plt.title("winner Count")
# Out:
# Text(0.5, 1.0, 'winner Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="win_by_wickets",
    color="black")
plt.title("win_by_wickets Count")
# Out:
# Text(0.5, 1.0, 'win_by_wickets Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="dl_applied",
    color="pink")
plt.title("dl_applied Count")
# Out:
# Text(0.5, 1.0, 'dl_applied Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="date",
    color="red")
plt.title("date Count")
# Out:
# Text(0.5, 1.0, 'date Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="win_by_runs",
    color="blue")
plt.title("win_by_runs Count")
# Out:
# Text(0.5, 1.0, 'win_by_runs Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="id",
    color="red")
plt.title("id Count")
# Out:
# Text(0.5, 1.0, 'id Count')
