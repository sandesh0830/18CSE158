# %% [markdown]
# <a href="https://colab.research.google.com/github/sandesh0830/18CSE158/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ASSIGNMENT-4**
# **NAME - SANDESH KUMAR BEHERA**
#
# **ROLL NO - 18CSE158**
#
# **SUBJECT - DMDW LAB**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd28d5c0-6bd2-4f9b-9023-a5eec87fa493" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd28d5c0-6bd2-4f9b-9023-a5eec87fa493">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving matches.csv to matches (3).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['matches.csv']))  
df
# Out:
#         id    Season  ...         umpire2                  umpire3
# 0        1  IPL-2017  ...        NJ Llong                      NaN
# 1        2  IPL-2017  ...          S Ravi                      NaN
# 2        3  IPL-2017  ...       CK Nandan                      NaN
# 3        4  IPL-2017  ...   C Shamshuddin                      NaN
# 4        5  IPL-2017  ...             NaN                      NaN
# ..     ...       ...  ...             ...                      ...
# 751  11347  IPL-2019  ...        O Nandan                   S Ravi
# 752  11412  IPL-2019  ...     Nitin Menon                Ian Gould
# 753  11413  IPL-2019  ...             NaN                      NaN
# 754  11414  IPL-2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415  IPL-2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=756, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df["umpire3"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               7
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["city"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             4
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["winner"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    4
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["player_of_match"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            2
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["umpire1"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            2
# umpire3            0
# dtype: int64

# %%
df["umpire2"].fillna("Unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# Season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %% [markdown]
# **The data is cleaned and ready to be used .**

# %% [markdown]
# Histogram

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="Season",
    color="red")
plt.title("Season Count")
# Out:
# Text(0.5, 1.0, 'Season Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(44,8))
sns.histplot(
    df,
    x="city",
    color="blue")
plt.title("city Count")
# Out:
# Text(0.5, 1.0, 'city Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(42,8))
sns.histplot(
    df,
    x="team1",
    color="skyblue")
plt.title("team1 Count")
# Out:
# Text(0.5, 1.0, 'team1 Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(44,8))
sns.histplot(
    df,
    x="team2",
    color="orange")
plt.title("team2 Count")
# Out:
# Text(0.5, 1.0, 'team2 Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="result",
    hue="result")
plt.title("result Count")
# Out:
# Text(0.5, 1.0, 'result Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(30,8))
sns.histplot(
    df,
    x="toss_decision",
    hue="toss_decision")
plt.title("toss_decision Count")
# Out:
# Text(0.5, 1.0, 'toss_decision Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(40,8))
sns.histplot(
    df,
    x="winner",
    color="red")
plt.title("winner Count")
# Out:
# Text(0.5, 1.0, 'winner Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="win_by_wickets",
    color="black")
plt.title("win_by_wickets Count")
# Out:
# Text(0.5, 1.0, 'win_by_wickets Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="dl_applied",
    color="pink")
plt.title("dl_applied Count")
# Out:
# Text(0.5, 1.0, 'dl_applied Count')

# %%
sns.set_theme(style="darkgrid")
f,ax=plt.subplots(figsize=(16,8))
sns.histplot(
    df,
    x="win_by_runs",
    color="blue")
plt.title("win_by_runs Count")
# Out:
# Text(0.5, 1.0, 'win_by_runs Count')

# %% [markdown]
# Bar Plot

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_wickets v/s winner")
sns.barplot(x="winner", y="win_by_wickets", data=df, color='skyblue')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s winner")
sns.barplot(x="winner", y="win_by_runs", data=df, color='red')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_wickets v/s city")
sns.barplot(x="city", y="win_by_wickets", data=df, color='green')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s city")
sns.barplot(x="city", y="win_by_runs", data=df, color='orange')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_wickets v/s Season")
sns.barplot(x="Season", y="win_by_wickets", data=df, color='pink')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s Season")
sns.barplot(x="Season", y="win_by_runs", data=df, color='gold')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s team1")
sns.barplot(x="team1", y="win_by_runs", data=df, color='grey')

# %% [markdown]
# Scatter Plot

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s team1")
sns.scatterplot(x="team1", y="win_by_runs", data=df, hue="team1")

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_runs v/s team2")
sns.scatterplot(x="team2", y="win_by_runs", data=df, color='blue')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("win_by_wickets v/s city")
sns.scatterplot(x="city", y="win_by_wickets", data=df, hue='city')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(32, 16))
plt.title("dl_applied v/s team1")
sns.scatterplot(x="dl_applied", y="team1", data=df, hue='dl_applied')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(25, 16))
plt.title("toss_winner v/s toss_decision")
sns.scatterplot(x="toss_decision", y="toss_winner", data=df, hue='toss_winner')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(32, 16))
plt.title("Season v/s result")
sns.scatterplot(x="result", y="Season", data=df, hue='result')

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 16))
plt.title("team2 v/s team1")
sns.scatterplot(x="team1", y="team2", data=df, hue='team2')

# %% [markdown]
# Pair Plot

# %%
sns.set_theme(style="ticks")
sns.pairplot(df, hue="player_of_match")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %% [markdown]
# Line Plot

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(40.5, 20.5))
sns.lineplot(x="team1", y="win_by_runs", 
             data=df,color='skyblue')

plt.xlabel('team1' )
plt.ylabel('win_by_runs')
plt.title("win_by_runs v/s team1")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(42, 20.5))
sns.lineplot(x="toss_winner", y="toss_decision", 
             data=df,color='red')

plt.xlabel('toss_winner' )
plt.ylabel('toss_decision')
plt.title("toss_winner v/s toss_decision")
plt.show()

# %%
sns.set_theme(style="darkgrid")
f, ax = plt.subplots(figsize=(40, 38))
sns.lineplot(x="team2", y="player_of_match", 
             data=df,color='gold')

plt.xlabel('team2' )
plt.ylabel('player_of_match')
plt.title("player_of_match v/s team2")
plt.show()

# %% [markdown]
# Box Plot

# %%
sns.set_theme(style="ticks", palette="pastel")
f, ax = plt.subplots(figsize=(32, 16))
sns.boxplot(x="winner", y="win_by_wickets",
            color='red', 
            data=df)

# %%
sns.set_theme(style="ticks", palette="pastel")
f, ax = plt.subplots(figsize=(32, 16))
sns.boxplot(x="winner", y="win_by_runs",
            color='red', 
            data=df)
